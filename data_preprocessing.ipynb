# %%
import pandas as pd

# %%
csv_file = r'C:\Users\jbubeck2\Downloads\langchain_csv-main\Data\Kununu_reviews_audi_bmw_mercedes.csv'
df = pd.read_csv(csv_file)
# Out:
# C:\Users\jbubeck2\AppData\Local\Temp\ipykernel_14600\1809276135.py:2: DtypeWarning: Columns (38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)

# %%
df.head()
# Out:
#                                title  score                  createdAt  \
# 0  Guter Arbeitgeber mit fairem Lohn    3.8  2022-02-17T00:00:00+00:00
# 1                          Vogelwild    2.9  2022-02-09T00:00:00+00:00
# 2                  Guter Arbeitgeber    4.3  2022-02-08T00:00:00+00:00
# 3              Leider nicht studiert    3.1  2022-01-31T00:00:00+00:00
# 4                    Top Arbeitgeber    4.7  2022-01-28T00:00:00+00:00
#
#                    updatedAt recommended  position  department job_state  \
# 0  2022-02-17T00:00:00+00:00        True  employee       sales   current
# 1  2022-02-09T00:00:00+00:00       False   manager    research   current
# 2  2022-02-08T00:00:00+00:00        True  employee       sales   current
# 3  2022-01-31T00:00:00+00:00       False  employee  operations   current
# 4  2022-01-28T00:00:00+00:00        True  employee    research   current
#
#    company.id        company.name  ... score_employmentSecurity  \
# ...

# %%
selected_columns = ["title", "score", "createdAt", "recommended", "position", "department", "job_state", "company.name", "company.location.city", "text_positive", "text_negative", "text_suggestion", "company", "ID"]

# %%
selected_df_100 = df[selected_columns].sample(n=100)

# %%
selected_df_1000 = df[selected_columns].sample(n=1000)

# %%
selected_df_2000 = df[selected_columns].sample(n=2000)

# %%
selected_df_5000 = df[selected_columns].sample(n=5000)

# %%
selected_df_100.head()
# Out:
#                                     title  score                  createdAt  \
# 195       Ein super Job,eine super Firma.    4.3  2019-07-08T00:00:00+00:00
# 2699  Innovativ und trotzdem konservativ.    3.8  2016-06-28T00:00:00+00:00
# 2293              Gut: 3.85 von 5 Sternen    3.8  2018-06-27T00:00:00+00:00
# 471                    AUDI AG, 4.2 von 5    4.2  2017-07-10T00:00:00+00:00
# 1213                           Referentin    4.7  2015-11-09T00:00:00+00:00
#
#      recommended  position   department job_state  \
# 195         True  employee   operations   current
# 2699        True  employee          NaN   current
# 2293        True  employee   operations   current
# 471         True  employee          NaN   current
# 1213        True  employee  controlling   current
#
#                              company.name company.location.city  \
# 195                                  Audi            Ingolstadt
# 2699  BMW Financial Services Holding GmbH               München
# ...

# %%
selected_df_100.to_csv('Data/HR-Analytics_kununu_reviews_100.csv', index=False)
selected_df_1000.to_csv('Data/HR-Analytics_kununu_reviews_1000.csv', index=False)
selected_df_2000.to_csv('Data/HR-Analytics_kununu_reviews_2000.csv', index=False)
selected_df_5000.to_csv('Data/HR-Analytics_kununu_reviews_5000.csv', index=False)
